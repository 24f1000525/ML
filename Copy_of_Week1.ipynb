# %% [markdown]
# <a href="https://colab.research.google.com/github/24f1000525/ML/blob/main/Copy_of_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import torch

# %% [markdown]
# ###DF -> python dictionary

# %% [markdown]
# ###File (csv,excel) --> pandas dataframe

# %%
df=pd.read_csv('/content/products_100.csv')

# %%
df
# Out:
#    product_name         type  price  quant
# 0     Product_1  Electronics   1299      5
# 1     Product_2  Electronics    999      8
# 2     Product_3  Electronics   1599      3
# 3     Product_4  Electronics    799     12
# 4     Product_5  Electronics   1899      4
# ..          ...          ...    ...    ...
# 95   Product_96         Home   1799      6
# 96   Product_97         Home   1999      5
# 97   Product_98         Home   2199      4
# 98   Product_99         Home   2399      3
# 99  Product_100         Home   2599      2
#
# [100 rows x 4 columns]

# %%
type(8)
# Out:
# int

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###Inspection

# %%
df.head(10)
# Out:
#   product_name         type  price  quant
# 0    Product_1  Electronics   1299      5
# 1    Product_2  Electronics    999      8
# 2    Product_3  Electronics   1599      3
# 3    Product_4  Electronics    799     12
# 4    Product_5  Electronics   1899      4
# 5    Product_6  Electronics    499     20
# 6    Product_7  Electronics    699     15
# 7    Product_8  Electronics    999     10
# 8    Product_9  Electronics   1299      7
# 9   Product_10  Electronics    399     25

# %%
df.tail(7)
# Out:
#    product_name  type  price  quant
# 93   Product_94  Home     70     90
# 94   Product_95  Home     85     75
# 95   Product_96  Home   1799      6
# 96   Product_97  Home   1999      5
# 97   Product_98  Home   2199      4
# 98   Product_99  Home   2399      3
# 99  Product_100  Home   2599      2

# %%
df.sample(10)
# Out:
#    product_name         type  price  quant
# 14   Product_15  Electronics     60     70
# 91   Product_92         Home     35    130
# 84   Product_85         Home   3499      1
# 97   Product_98         Home   2199      4
# 92   Product_93         Home     50    110
# 57   Product_58      Grocery   2299      3
# 73   Product_74      Grocery    160     36
# 74   Product_75      Grocery    140     38
# 46   Product_47     Clothing    349     28
# 85   Product_86         Home    749     16

# %%
df.columns #strings are called object in pandas
# Out:
# Index(['product_name', 'type', 'price', 'quant'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  100 non-null    object
#  1   type          100 non-null    object
#  2   price         100 non-null    int64
#  3   quant         100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.3+ KB

# %% [markdown]
# see row 2 to row 6

# %%
df.head(6).tail(5).sample(2)
# Out:
#   product_name         type  price  quant
# 1    Product_2  Electronics    999      8
# 4    Product_5  Electronics   1899      4

# %% [markdown]
# Dimensional Inspection

# %%
df.shape
# Out:
# (100, 4)

# %%
df.shape[0]*df.shape[1] # ==df.size
# Out:
# 400

# %%
df.size
# Out:
# 400

# %% [markdown]
# Filtering

# %%
df.head()
# Out:
#   product_name         type  price  quant
# 0    Product_1  Electronics   1299      5
# 1    Product_2  Electronics    999      8
# 2    Product_3  Electronics   1599      3
# 3    Product_4  Electronics    799     12
# 4    Product_5  Electronics   1899      4

# %%
df['product_name']
# Out:
# 0       Product_1
# 1       Product_2
# 2       Product_3
# 3       Product_4
# 4       Product_5
#          ...
# 95     Product_96
# 96     Product_97
# 97     Product_98
# 98     Product_99
# 99    Product_100
# Name: product_name, Length: 100, dtype: object

# %%
df['price'].tail()
# Out:
# 95    1799
# 96    1999
# 97    2199
# 98    2399
# 99    2599
# Name: price, dtype: int64

# %%
df.head()
# Out:
#   product_name         type  price  quant
# 0    Product_1  Electronics   1299      5
# 1    Product_2  Electronics    999      8
# 2    Product_3  Electronics   1599      3
# 3    Product_4  Electronics    799     12
# 4    Product_5  Electronics   1899      4

# %% [markdown]
# #Average Price

# %%
print(df['price'].mean())
# Out:
# 1576.55

# %%
print(df['price'].median())
# Out:
# 1024.0

# %%
print(df['price'].std())
# Out:
# 1722.3201545143872

# %%
print(df['quant'].median())
# Out:
# 9.5

# %% [markdown]
# ##Shortcut

# %%
df.describe()
# Out:
#              price       quant
# count   100.000000  100.000000
# mean   1576.550000   23.220000
# std    1722.320155   31.891096
# min      25.000000    1.000000
# 25%     276.750000    3.000000
# 50%    1024.000000    9.500000
# 75%    2049.000000   30.000000
# max    8999.000000  150.000000

# %%
print(df['quant'].mode())
# Out:
# 0    2
# Name: quant, dtype: int64

# %%
df[df['quant']==2]
# Out:
#    product_name         type  price  quant
# 20   Product_21  Electronics   2499      2
# 23   Product_24  Electronics   3499      2
# 36   Product_37     Clothing   2499      2
# 41   Product_42     Clothing   6499      2
# 44   Product_45     Clothing   4599      2
# 56   Product_57      Grocery   2799      2
# 60   Product_61      Grocery   3999      2
# 61   Product_62      Grocery   4299      2
# 82   Product_83         Home   2899      2
# 83   Product_84         Home   3199      2
# 99  Product_100         Home   2599      2

# %%
df['type'].unique()
# Out:
# array(['Electronics', 'Clothing', 'Grocery', 'Home'], dtype=object)

# %%
df['type'].nunique()
# Out:
# 4

# %%
df['type'].value_counts()  #frequency distribution
# Out:
# type
# Electronics    25
# Clothing       25
# Grocery        25
# Home           25
# Name: count, dtype: int64

# %%
df['product_name'].value_counts()
# Out:
# product_name
# Product_1      1
# Product_2      1
# Product_3      1
# Product_4      1
# Product_5      1
#               ..
# Product_96     1
# Product_97     1
# Product_98     1
# Product_99     1
# Product_100    1
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# Filtering based on condition

# %% [markdown]
# i want only electronics

# %%
df.tail()
# Out:
#    product_name  type  price  quant
# 95   Product_96  Home   1799      6
# 96   Product_97  Home   1999      5
# 97   Product_98  Home   2199      4
# 98   Product_99  Home   2399      3
# 99  Product_100  Home   2599      2

# %%
df[df['type']=='Electronics']
# Out:
#    product_name         type  price  quant
# 0     Product_1  Electronics   1299      5
# 1     Product_2  Electronics    999      8
# 2     Product_3  Electronics   1599      3
# 3     Product_4  Electronics    799     12
# 4     Product_5  Electronics   1899      4
# 5     Product_6  Electronics    499     20
# 6     Product_7  Electronics    699     15
# 7     Product_8  Electronics    999     10
# 8     Product_9  Electronics   1299      7
# 9    Product_10  Electronics    399     25
# 10   Product_11  Electronics    120     50
# 11   Product_12  Electronics     80     60
# 12   Product_13  Electronics    150     40
# 13   Product_14  Electronics    200     35
# 14   Product_15  Electronics     60     70
# 15   Product_16  Electronics    899      9
# 16   Product_17  Electronics   1299      6
# 17   Product_18  Electronics   1599      5
# 18   Product_19  Electronics    699     14
# 19   Product_20  Electronics    499     18
# 20   Product_21  Electronics   2499      2
# ...

# %%
df[df['price']<=500]
# Out:
#    product_name         type  price  quant
# 5     Product_6  Electronics    499     20
# 9    Product_10  Electronics    399     25
# 10   Product_11  Electronics    120     50
# 11   Product_12  Electronics     80     60
# 12   Product_13  Electronics    150     40
# 13   Product_14  Electronics    200     35
# 14   Product_15  Electronics     60     70
# 19   Product_20  Electronics    499     18
# 30   Product_31     Clothing     90     55
# 31   Product_32     Clothing    110     45
# 32   Product_33     Clothing     75     65
# 33   Product_34     Clothing    130     48
# 34   Product_35     Clothing     95     58
# 45   Product_46     Clothing    299     30
# 46   Product_47     Clothing    349     28
# 47   Product_48     Clothing    449     22
# 50   Product_51      Grocery     30    120
# 51   Product_52      Grocery     45     95
# 52   Product_53      Grocery     55     85
# 53   Product_54      Grocery     65     78
# 54   Product_55      Grocery     40    100
# ...

# %%
df[(df['quant']==50) | (df['type']=='Electronics')]
# Out:
#    product_name         type  price  quant
# 0     Product_1  Electronics   1299      5
# 1     Product_2  Electronics    999      8
# 2     Product_3  Electronics   1599      3
# 3     Product_4  Electronics    799     12
# 4     Product_5  Electronics   1899      4
# 5     Product_6  Electronics    499     20
# 6     Product_7  Electronics    699     15
# 7     Product_8  Electronics    999     10
# 8     Product_9  Electronics   1299      7
# 9    Product_10  Electronics    399     25
# 10   Product_11  Electronics    120     50
# 11   Product_12  Electronics     80     60
# 12   Product_13  Electronics    150     40
# 13   Product_14  Electronics    200     35
# 14   Product_15  Electronics     60     70
# 15   Product_16  Electronics    899      9
# 16   Product_17  Electronics   1299      6
# 17   Product_18  Electronics   1599      5
# 18   Product_19  Electronics    699     14
# 19   Product_20  Electronics    499     18
# 20   Product_21  Electronics   2499      2
# ...

# %%
df[(df['type']=='Home') | (df['type']=='Electronics') ]
# Out:
#    product_name         type  price  quant
# 0     Product_1  Electronics   1299      5
# 1     Product_2  Electronics    999      8
# 2     Product_3  Electronics   1599      3
# 3     Product_4  Electronics    799     12
# 4     Product_5  Electronics   1899      4
# 5     Product_6  Electronics    499     20
# 6     Product_7  Electronics    699     15
# 7     Product_8  Electronics    999     10
# 8     Product_9  Electronics   1299      7
# 9    Product_10  Electronics    399     25
# 10   Product_11  Electronics    120     50
# 11   Product_12  Electronics     80     60
# 12   Product_13  Electronics    150     40
# 13   Product_14  Electronics    200     35
# 14   Product_15  Electronics     60     70
# 15   Product_16  Electronics    899      9
# 16   Product_17  Electronics   1299      6
# 17   Product_18  Electronics   1599      5
# 18   Product_19  Electronics    699     14
# 19   Product_20  Electronics    499     18
# 20   Product_21  Electronics   2499      2
# ...

# %%
df[(df['price']<500) & (df['type'] == 'Electronics')]
# Out:
#    product_name         type  price  quant
# 5     Product_6  Electronics    499     20
# 9    Product_10  Electronics    399     25
# 10   Product_11  Electronics    120     50
# 11   Product_12  Electronics     80     60
# 12   Product_13  Electronics    150     40
# 13   Product_14  Electronics    200     35
# 14   Product_15  Electronics     60     70
# 19   Product_20  Electronics    499     18

# %% [markdown]
# **Categorical Values and Corelation**

# %%
#df.corr()

# %%
df[['price', 'quant']].corr()
# Out:
#           price     quant
# price  1.000000 -0.528948
# quant -0.528948  1.000000

# %% [markdown]
# Categorical Values can be changed to Label Encoding or One Hot Encoding

# %%
categorical_cols = df.select_dtypes(include=['object'])
print(categorical_cols.head())
# Out:
#   product_name         type
# 0    Product_1  Electronics
# 1    Product_2  Electronics
# 2    Product_3  Electronics
# 3    Product_4  Electronics
# 4    Product_5  Electronics

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64'])
print(numerical_cols.head())
# Out:
#    price  quant
# 0   1299      5
# 1    999      8
# 2   1599      3
# 3    799     12
# 4   1899      4

# %%
df['type_encoded'] = df['type'].astype('category').cat.codes

print(df[['type', 'type_encoded']].tail())
# Out:
#     type  type_encoded
# 95  Home             3
# 96  Home             3
# 97  Home             3
# 98  Home             3
# 99  Home             3

# %%
df[['type_encoded','price', 'quant']].corr()
# Out:
#               type_encoded     price     quant
# type_encoded      1.000000 -0.058600  0.134173
# price            -0.058600  1.000000 -0.528948
# quant             0.134173 -0.528948  1.000000

# %% [markdown]
# One Hot Encoding

# %%
df_encoded = pd.get_dummies(df, columns=['type'], dtype='int64')

# %% [markdown]
# [1000
# 0100
# 0010
# 0001]

# %%
df_encoded
# Out:
#    product_name  price  quant  type_encoded  type_Clothing  type_Electronics  \
# 0     Product_1   1299      5             1              0                 1
# 1     Product_2    999      8             1              0                 1
# 2     Product_3   1599      3             1              0                 1
# 3     Product_4    799     12             1              0                 1
# 4     Product_5   1899      4             1              0                 1
# ..          ...    ...    ...           ...            ...               ...
# 95   Product_96   1799      6             3              0                 0
# 96   Product_97   1999      5             3              0                 0
# 97   Product_98   2199      4             3              0                 0
# 98   Product_99   2399      3             3              0                 0
# 99  Product_100   2599      2             3              0                 0
#
#     type_Grocery  type_Home
# ...

# %%
df_encoded[['type_Clothing','type_Electronics','type_Grocery','type_Home','price', 'quant']].corr()
# Out:
#                   type_Clothing  type_Electronics  type_Grocery  type_Home  \
# type_Clothing          1.000000         -0.333333     -0.333333  -0.333333
# type_Electronics      -0.333333          1.000000     -0.333333  -0.333333
# type_Grocery          -0.333333         -0.333333      1.000000  -0.333333
# type_Home             -0.333333         -0.333333     -0.333333   1.000000
# price                  0.123526         -0.141820      0.064366  -0.046072
# quant                 -0.071688         -0.110990      0.090611   0.092067
#
#                      price     quant
# type_Clothing     0.123526 -0.071688
# type_Electronics -0.141820 -0.110990
# type_Grocery      0.064366  0.090611
# type_Home        -0.046072  0.092067
# price             1.000000 -0.528948
# quant            -0.528948  1.000000

# %% [markdown]
# Indexing, loc and iloc

# %%
 price =df['price'].tolist()

# %%
df[['price','quant']]
# Out:
#     price  quant
# 0    1299      5
# 1     999      8
# 2    1599      3
# 3     799     12
# 4    1899      4
# ..    ...    ...
# 95   1799      6
# 96   1999      5
# 97   2199      4
# 98   2399      3
# 99   2599      2
#
# [100 rows x 2 columns]

# %%
df[10:15]
# Out:
#    product_name         type  price  quant  type_encoded
# 10   Product_11  Electronics    120     50             1
# 11   Product_12  Electronics     80     60             1
# 12   Product_13  Electronics    150     40             1
# 13   Product_14  Electronics    200     35             1
# 14   Product_15  Electronics     60     70             1

# %%
df[0:4]
# Out:
#   product_name         type  price  quant  type_encoded
# 0    Product_1  Electronics   1299      5             1
# 1    Product_2  Electronics    999      8             1
# 2    Product_3  Electronics   1599      3             1
# 3    Product_4  Electronics    799     12             1

# %%
df.loc[0]  # df[0] gives error hence iloc and loc
# Out:
# product_name      Product_1
# type            Electronics
# price                  1299
# quant                     5
# type_encoded              1
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# product_name      Product_1
# type            Electronics
# price                  1299
# quant                     5
# type_encoded              1
# Name: 0, dtype: object

# %%
df.loc[df['quant']>20][0:5]
# Out:
#    product_name         type  price  quant  type_encoded
# 9    Product_10  Electronics    399     25             1
# 10   Product_11  Electronics    120     50             1
# 11   Product_12  Electronics     80     60             1
# 12   Product_13  Electronics    150     40             1
# 13   Product_14  Electronics    200     35             1

# %%
df.loc[df['type'] == 'Grocery'][0:5]
# Out:
#    product_name     type  price  quant  type_encoded
# 50   Product_51  Grocery     30    120             2
# 51   Product_52  Grocery     45     95             2
# 52   Product_53  Grocery     55     85             2
# 53   Product_54  Grocery     65     78             2
# 54   Product_55  Grocery     40    100             2

# %%
df.iloc[5:10, 1:]  # first argument rows and second agrument columns
# Out:
#           type  price  quant  type_encoded
# 5  Electronics    499     20             1
# 6  Electronics    699     15             1
# 7  Electronics    999     10             1
# 8  Electronics   1299      7             1
# 9  Electronics    399     25             1

# %% [markdown]
# GroupBy
#
# Split → Split data by category
#
# Apply → Apply function (aggregate functions)
#
# Combine → Combine results

# %%
df.groupby('type')['price'].max()
# Out:
# type
# Clothing       8999
# Electronics    3499
# Grocery        5699
# Home           3499
# Name: price, dtype: int64

# %%
df.groupby('type').agg({
    'price': ['mean', 'max', 'min'],
    'quant': ['mean', 'sum']
})
# Out:
#               price            quant
#                mean   max min   mean  sum
# type
# Clothing     1943.2  8999  75  19.28  482
# Electronics  1155.6  3499  60  17.12  428
# Grocery      1767.6  5699  30  28.20  705
# Home         1439.8  3499  25  28.28  707

# %%
df.groupby('type')['product_name'].count()
# Out:
# type
# Clothing       25
# Electronics    25
# Grocery        25
# Home           25
# Name: product_name, dtype: int64

# %%
df.groupby(['type'])[['price', 'quant']].mean()
# Out:
#               price  quant
# type
# Clothing     1943.2  19.28
# Electronics  1155.6  17.12
# Grocery      1767.6  28.20
# Home         1439.8  28.28

# %%
df['revenue'] = df['price'] * df['quant']

df.groupby('type')['revenue'].mean()
# Out:
# type
# Clothing       8746.56
# Electronics    7393.08
# Grocery        6468.12
# Home           8770.92
# Name: revenue, dtype: float64

# %% [markdown]
# Sorting in Dataframes

# %%
df_sorted = df.sort_values('price',ascending=False)

# %%
df_sorted.head()
# Out:
#    product_name      type  price  quant  type_encoded  revenue
# 40   Product_41  Clothing   8999      1             0     8999
# 42   Product_43  Clothing   7499      1             0     7499
# 41   Product_42  Clothing   6499      2             0    12998
# 64   Product_65   Grocery   5699      1             2     5699
# 43   Product_44  Clothing   5499      3             0    16497

# %%
df.head()
# Out:
#   product_name         type  price  quant  type_encoded  revenue
# 0    Product_1  Electronics   1299      5             1     6495
# 1    Product_2  Electronics    999      8             1     7992
# 2    Product_3  Electronics   1599      3             1     4797
# 3    Product_4  Electronics    799     12             1     9588
# 4    Product_5  Electronics   1899      4             1     7596

# %%
df.sort_values(['type', 'price'], ascending=[True, False])
# Out:
#    product_name      type  price  quant  type_encoded  revenue
# 40   Product_41  Clothing   8999      1             0     8999
# 42   Product_43  Clothing   7499      1             0     7499
# 41   Product_42  Clothing   6499      2             0    12998
# 43   Product_44  Clothing   5499      3             0    16497
# 44   Product_45  Clothing   4599      2             0     9198
# ..          ...       ...    ...    ...           ...      ...
# 94   Product_95      Home     85     75             3     6375
# 93   Product_94      Home     70     90             3     6300
# 92   Product_93      Home     50    110             3     5500
# 91   Product_92      Home     35    130             3     4550
# 90   Product_91      Home     25    150             3     3750
#
# [100 rows x 6 columns]

# %%
df.sort_index()
# Out:
#    product_name         type  price  quant  type_encoded  revenue
# 0     Product_1  Electronics   1299      5             1     6495
# 1     Product_2  Electronics    999      8             1     7992
# 2     Product_3  Electronics   1599      3             1     4797
# 3     Product_4  Electronics    799     12             1     9588
# 4     Product_5  Electronics   1899      4             1     7596
# ..          ...          ...    ...    ...           ...      ...
# 95   Product_96         Home   1799      6             3    10794
# 96   Product_97         Home   1999      5             3     9995
# 97   Product_98         Home   2199      4             3     8796
# 98   Product_99         Home   2399      3             3     7197
# 99  Product_100         Home   2599      2             3     5198
#
# [100 rows x 6 columns]

# %%
df_sorted = df.sort_values('price').reset_index(drop=True)

# %%
df.head()
# Out:
#   product_name         type  price  quant  type_encoded  revenue
# 0    Product_1  Electronics   1299      5             1     6495
# 1    Product_2  Electronics    999      8             1     7992
# 2    Product_3  Electronics   1599      3             1     4797
# 3    Product_4  Electronics    799     12             1     9588
# 4    Product_5  Electronics   1899      4             1     7596

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#   product_name         type  price  quant  type_encoded  revenue
# 0    Product_1  Electronics   1299      5             1     6495
# 1    Product_2  Electronics    999      8             1     7992
# 2    Product_3  Electronics   1599      3             1     4797
# 3    Product_4  Electronics    799     12             1     9588
# 4    Product_5  Electronics   1899      4             1     7596

# %%
df_copy.sort_values('price')
# Out:
#    product_name      type  price  quant  type_encoded  revenue
# 90   Product_91      Home     25    150             3     3750
# 50   Product_51   Grocery     30    120             2     3600
# 91   Product_92      Home     35    130             3     4550
# 54   Product_55   Grocery     40    100             2     4000
# 51   Product_52   Grocery     45     95             2     4275
# ..          ...       ...    ...    ...           ...      ...
# 43   Product_44  Clothing   5499      3             0    16497
# 64   Product_65   Grocery   5699      1             2     5699
# 41   Product_42  Clothing   6499      2             0    12998
# 42   Product_43  Clothing   7499      1             0     7499
# 40   Product_41  Clothing   8999      1             0     8999
#
# [100 rows x 6 columns]

# %%
df_copy.head()
# Out:
#   product_name         type  price  quant  type_encoded  revenue
# 0    Product_1  Electronics   1299      5             1     6495
# 1    Product_2  Electronics    999      8             1     7992
# 2    Product_3  Electronics   1599      3             1     4797
# 3    Product_4  Electronics    799     12             1     9588
# 4    Product_5  Electronics   1899      4             1     7596

# %% [markdown]
# Plotting in Pandas

# %%
df['type'].hist()
# Out:
# <Axes: >

# %%
df['price'].plot()
# Out:
# <Axes: >

# %%
df['price'].plot(title="Price Trend")
# Out:
# <Axes: title={'center': 'Price Trend'}>

# %%
df.groupby('type')['price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='type'>

# %%
df['price'].plot(kind='hist', bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='price', y='quant')
# Out:
# <Axes: xlabel='price', ylabel='quant'>

# %% [markdown]
# #
