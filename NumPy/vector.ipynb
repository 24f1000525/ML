# %%
import numpy as np

# %% [markdown]
# vectors representation in numpy

# %%
x=np.array([2,5,3,7])
y=np.array([4,6,7,5])

# %% [markdown]
# vector addition

# %%
z=x+y
z
# Out:
# array([ 6, 11, 10, 12])

# %% [markdown]
# element wise multiplication

# %%
z=x*y
z
# Out:
# array([ 8, 30, 21, 35])

# %% [markdown]
# scaling vectors

# %%
z=3*x
z
# Out:
# array([ 6, 15,  9, 21])

# %% [markdown]
# element wise function of vectors

# %%
z=x**2
z
# Out:
# array([ 4, 25,  9, 49])

# %%
z=np.log(x)
z
# Out:
# array([0.69314718, 1.60943791, 1.09861229, 1.94591015])

# %% [markdown]
# dot product

# %%
z=np.dot(x,y)
z
# Out:
# np.int64(94)

# %% [markdown]
# shape of vector

# %%
x.shape
x.shape[0]==len(x)
# Out:
# True

# %% [markdown]
# vectors with all zero

# %%
s=np.array([0 for _ in range(4)])
s
# Out:
# array([0, 0, 0, 0])

# %%
s=np.ones(6)
s
# Out:
# array([1., 1., 1., 1., 1., 1.])

# %%
s=np.zeros(5)
s
# Out:
# array([0., 0., 0., 0., 0.])
